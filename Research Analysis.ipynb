# %%
from csv_diff import load_csv, compare
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
Demo = pd.read_csv('Files/CR-demographic.csv', header = 1)[9:]

# %%
Demo_01 = pd.read_csv('Files/CR-expertdemographic.csv', header = 1)[25:]

# %% [markdown]
# Participant's gender distribution (student)

# %%
# Histgram of Participant's gender distribution.
x = Demo["Please select your sex:"].value_counts()
y = Demo["Please select your sex:"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's gender distribution")
plt.xlabel("sample")
plt.ylabel("gender") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Pics/Research Analysis/sex-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's gender distribution.
plt.figure(figsize=[9,7])
Demo["Please select your sex:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Gender distribution")
plt.savefig(os.path.join('Pics/Research Analysis/sex-pie.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participant's gender distribution (expert)

# %%
# Histgram of Participant's gender distribution.
x = Demo_01["Please select your sex:"].value_counts()
y = Demo_01["Please select your sex:"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's gender distribution (expert)")
plt.xlabel("sample")
plt.ylabel("gender") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Expert Pics/Research Analysis/sex-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's gender distribution.
plt.figure(figsize=[9,7])
Demo_01["Please select your sex:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Gender distribution (expert)")
plt.savefig(os.path.join('Expert Pics/Research Analysis/sex-pie.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participants academic statues (student)

# %%
x = Demo["Please select your academic status:"].value_counts()
y = Demo["Please select your academic status:"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's academic statues")
plt.xlabel("sample")
plt.ylabel("academic statues") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Pics/Research Analysis/acad-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's academic statues distribution.
plt.figure(figsize=[9,7])
Demo["Please select your academic status:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Academic statues")
plt.ylabel("academic statues") 

plt.savefig(os.path.join('Pics/Research Analysis/acad-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participants academic statues (expert)

# %%
x = Demo_01["Please select your academic status:"].value_counts()
y = Demo_01["Please select your academic status:"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's academic statues (expert)")
plt.xlabel("sample")
plt.ylabel("academic statues") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Expert Pics/Research Analysis/acad-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's academic statues distribution.
plt.figure(figsize=[9,7])
Demo_01["Please select your academic status:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Academic statues (expert)")
plt.ylabel("academic statues") 

plt.savefig(os.path.join('Expert Pics/Research Analysis/acad-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participant age range (student)

# %%
Demo["Please select your age range:"].value_counts()
# Out:
# 20-49    16
# Name: Please select your age range:, dtype: int64

# %%
df = pd.DataFrame({'age':['<20', '20-49', '50-59','60-69', '>69'], 'population':[0, 16, 0, 0, 0]})
df.plot.barh(x='age', y='population')
plt.title("Participant's age range")
plt.xlabel("sample")
plt.ylabel("age range") 

plt.savefig(os.path.join('Pics/Research Analysis/age-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's age range distribution.
plt.figure(figsize=[9,7])
Demo["Please select your age range:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Age range")
plt.ylabel("age range") 

plt.savefig(os.path.join('Pics/Research Analysis/age-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participant age range (expert)

# %%
Demo_01["Please select your age range:"].value_counts()
# Out:
# >69      3
# 20-49    3
# 50-59    2
# 60-69    1
# Name: Please select your age range:, dtype: int64

# %%
df = pd.DataFrame({'age':['<20', '20-49', '50-59','60-69', '>69'], 'population':[0, 3, 2, 1, 3]})
df.plot.barh(x='age', y='population')
plt.title("Participant's age range (expert)")
plt.xlabel("sample")
plt.ylabel("age range") 
plt.xticks([0, 1, 2, 3])

for i, v in enumerate(df["population"]):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')


plt.savefig(os.path.join('Expert Pics/Research Analysis/age-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's age range distribution.
plt.figure(figsize=[9,7])
Demo_01["Please select your age range:"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Age range (expert)")
plt.ylabel("age range") 

plt.savefig(os.path.join('Expert Pics/Research Analysis/age-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participant's best describes your knowledge of morphological characters of Carex (student)

# %%
x = Demo["Please select the statement that best describes your knowledge of morphological characters of Carex. [Select the last option that applies to you]"].value_counts()
y = Demo["Please select the statement that best describes your knowledge of morphological characters of Carex. [Select the last option that applies to you]"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's knowledge situation")
plt.xlabel("sample")
plt.ylabel("situation") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Pics/Research Analysis/know-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's knowledge situation distribution.
plt.figure(figsize=[9,7])
Demo["Please select the statement that best describes your knowledge of morphological characters of Carex. [Select the last option that applies to you]"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Knowledge situation")
plt.ylabel("knowledge statues") 

plt.savefig(os.path.join('Pics/Research Analysis/know-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Participant's best describes your knowledge of morphological characters of Carex (expert)

# %%
x = Demo_01["Please select the statement that best describes your knowledge of to. [Select the last option that applies to you]"].value_counts()
y = Demo_01["Please select the statement that best describes your knowledge of to. [Select the last option that applies to you]"].value_counts().tolist()
x.plot.barh()
plt.title("Participant's knowledge situation (expert)")
plt.xlabel("sample")
plt.ylabel("situation") 

for i, v in enumerate(y):
    plt.text(v - 0.8, i - 0.03 , str(v), color='black', fontweight='bold')

plt.savefig(os.path.join('Expert Pics/Research Analysis/know-hist.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Pie chart of Participant's knowledge situation distribution.
plt.figure(figsize=[9,7])
Demo_01["Please select the statement that best describes your knowledge of to. [Select the last option that applies to you]"].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Knowledge situation (expert)")
plt.ylabel("knowledge statues") 

plt.savefig(os.path.join('Expert Pics/Research Analysis/know-bar.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()
