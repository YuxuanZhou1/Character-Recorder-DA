# %%
from csv_diff import load_csv, compare
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
PA = pd.read_csv('Files/CR-studentexperiences.csv', header = 1)[1:]
PA.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4     start       end  \
# 1        m01        NaN        NaN        NaN        yes  15:36:03  15:50:03
# 2        m02        NaN        NaN        NaN        yes  15:13:11  15:24:47
# 3        p01        NaN        NaN     123456        yes  15:47:30  15:57:37
# 4        p03        NaN        NaN     123456        yes  16:15:42  16:36:10
# 5        p04        NaN        NaN     182367        yes  14:10:06  14:24:08
#
#     start.1     end.1   start.2 used others values? use my terms  \
# 1  15:27:38  15:32:40  15:50:27                 NaN          NaN
# 2  15:06:33  15:11:36  15:25:09                 NaN          NaN
# 3  15:41:21  15:46:25  16:00:00                 NaN          NaN
# 4  16:05:45  16:10:37  16:38:51                 NaN          NaN
# 5  14:04:48  14:08:36  14:26:26                 NaN          NaN
#
#   refer back to tutorial     end.2 Unnamed: 14 Unnamed: 15  zip  \
# ...

# %%
PA = PA[7:]
a = [i for i in range(0, 16)]
PA = PA.set_index([pd.Index(a)])

# %% [markdown]
# The distribution about User's special behaviors

# %%
fig, ax = plt.subplots()
PA["used others values?"].dropna().astype('int32').plot()
PA["use my terms"].dropna().astype('int32').plot()
PA["refer back to tutorial"].dropna().astype('int32').plot()
ax.legend(['used others values', 'use my terms', 'refer back to tutorial'])

plt.title("Participant's behavior distribution")
plt.xlabel("PID")
plt.ylabel("Times") 

plt.savefig(os.path.join('Pics/Exploring Analysis/Users special behaviors_1.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
df = PA[["used others values?", "use my terms", "refer back to tutorial"]].dropna().astype('int32')
df.plot.bar(rot = 0, stacked = True)

plt.title("Participant's behavior bar chart")
plt.xlabel("PID")
plt.ylabel("Times")

plt.savefig(os.path.join('Pics/Exploring Analysis/Users special behaviors_2.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# How many times user used others values

# %%
fig, ax = plt.subplots()
PA["used others values?"].dropna().astype('int32').plot()

plt.title("Participant's userd others values")
plt.xlabel("PID")
plt.ylabel("Times") 
plt.savefig(os.path.join('Pics/Exploring Analysis/Users used others values.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Hom many times user used their own terms

# %%
fig, ax = plt.subplots()
PA["use my terms"].dropna().astype('int32').plot()

plt.title("Participant's userd others values")
plt.xlabel("PID")
plt.ylabel("Times") 

plt.savefig(os.path.join('Pics/Exploring Analysis/Users used their own terms.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Hom many times user refer back to turtorial

# %%
fig, ax = plt.subplots()
PA["refer back to tutorial"].dropna().astype('int32').plot()

plt.title("Participant's refer back to turtorial")
plt.xlabel("PID")
plt.ylabel("Times") 

plt.savefig(os.path.join('Pics/Exploring Analysis/Users refer turtorial.png'), dpi=300, format='png', bbox_inches='tight')
plt.show()
